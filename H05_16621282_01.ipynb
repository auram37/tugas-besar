# %%
# NIM/Nama : 16621282/Aura Maharani
# Tanggal : 1 Desember 2021
# Deskripsi : Program Analaisis Data

# %%
import pandas as pd

# %%
df = pd.read_csv("./downloads/H05.csv")

# %%
df
# Out:
#                                 nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0               Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1                     Steven Margono    FMIPA      67.43      51.50      57.20
# 2                       Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3               Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4                   Alvin Natawiguna     FTSL      65.45      57.67      56.39
# 5                      Sasti Safitri     FTSL      60.58      41.91      51.55
# 6                Dani Yulianto Putra     FTSL      51.67      35.05      48.69
# 7     Nabila Febitsukarizky Bunyamin     FTTM      71.66      67.61      69.75
# 8                Ratna Siti Khodijah      FTI      73.06      59.16      59.48
# 9                       Gita Partiwi     FTSL      69.57      38.84      48.17
# 10             M Dharin Detama Patra     FITB      64.76      56.89      59.13
# ...

# %%
df_jumlah = len(df)
print("Banyaknya data adalah",df_jumlah)
# Out:
# Banyaknya data adalah 5135

# %%
print("10 data pertama adalah",df.head(10))
# Out:
# 10 data pertama adalah                              nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 0            Farhan Fathur Rahman    FMIPA      57.21      34.14      38.93
# 1                  Steven Margono    FMIPA      67.43      51.50      57.20
# 2                    Ryan Sentosa    SAPPK      90.62      37.38      40.73
# 3            Muhajah Babny Muslim    FMIPA      72.31      38.80      44.79
# 4                Alvin Natawiguna     FTSL      65.45      57.67      56.39
# 5                   Sasti Safitri     FTSL      60.58      41.91      51.55
# 6             Dani Yulianto Putra     FTSL      51.67      35.05      48.69
# 7  Nabila Febitsukarizky Bunyamin     FTTM      71.66      67.61      69.75
# 8             Ratna Siti Khodijah      FTI      73.06      59.16      59.48
# 9                    Gita Partiwi     FTSL      69.57      38.84      48.17

# %%
print("Data ke-50 sampai ke-10 adalah",df.iloc[50:61])
# Out:
# Data ke-50 sampai ke-10 adalah                         nama fakultas  nilai_mat  nilai_kim  nilai_fis
# 50      Arief Syakur Sutedjo     FTTM      84.40      61.21      73.91
# 51         Fayi Raihan Saleh    FMIPA      60.62      32.57      42.34
# 52          Erna Kristiawati      FTI      67.48      46.78      52.30
# 53                    Albert    SAPPK      70.27      50.10      54.01
# 54  M Jazztyan Indra Pradana     STEI      53.40      43.06      60.30
# 55      Moch Ginanjar Busiri    FMIPA      74.29      38.44      49.15
# 56              Aisya Tamara     FITB      71.49      35.86      37.41
# 57        Tyas Arum Widayati    SAPPK      68.57      37.02      53.25
# 58                Arif Saleh      FTI     100.00      59.79      55.33
# 59     Windy Diwita Nisaekti      FTI      67.15      57.72      54.24
# 60             Alif Aviano S     STEI      54.11      58.01      73.17

# %%
jumlah = df['fakultas'].value_counts()
print("Banyak mahasiswa tiap fakultas adalah",jumlah)
# Out:
# Banyak mahasiswa tiap fakultas adalah FTI      834
# STEI     777
# FTSL     660
# FMIPA    627
# FTTM     579
# FTMD     480
# FITB     403
# SAPPK    315
# SITHR    282
# SITHS    178
# Name: fakultas, dtype: int64

# %%
print("Nilai korelasi antara nilai fisika dan kimia adalah",df["nilai_kim"].corr(df["nilai_fis"]),"karena nilai korelasi mendekati satu, maka nilai fisika dan kimia berbanding lurus")
# Out:
# Nilai korelasi antara nilai fisika dan kimia adalah 0.798818742388 karena nilai korelasi mendekati satu, maka nilai fisika dan kimia berbanding lurus
